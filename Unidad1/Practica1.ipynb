# %% [markdown]
# <a href="https://colab.research.google.com/github/CorralMarquez/Probabilidad-/blob/main/Unidad1/Practica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y estadistica
#
# #Unidad 1
#
# ## Practica 1: **Estadistica descriptiva e histogramas**
#
# Docente: Jose Gabriel Rodriguez Rivas
#
# Alumno: Jose Gerardo Corral Marquez

# %%
from statistics import mean, median

# %%
# Lista de calificaciones del grupo de probabilidad y estadistica
Grupoa =[70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]
print (Grupoa)
type (Grupoa)
# Out:
# [70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]
# list

# %%
promedio = sum(Grupoa) / len(Grupoa)

# %%
#utilizar la funcion mean que esta en la libreria estatistics para sacar el promedio

promedio2 = mean(Grupoa)
print ("El promedio de Grupoa es=", promedio2)
# Out:
# El promedio de Grupoa es= 75.81818181818181

# %% [markdown]
# #Determinar la mediana del ejemplo 1

# %%
# Calcular mediana
mediana = median(Grupoa)
print("Mediana:", mediana)
# Out:
# Mediana: 80

# %%
from statistics import mean

# %%
Grupos =[70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]
type (Grupos)
print(Grupos)
# Out:
# [70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]

# %%
# En caso de que exista mas de una moda, se puede emplear la funcion miltimode para sacar las multiples modas que pueden existir

from statistics import multimode
moda2 = multimode(Grupos)
print(moda2)
# Out:
# [100]

# %% [markdown]
# Ejemplo2. Tiempo de 100 metros de un grupo de 12 alumnos

# %%
#definimos una de las variables llamada tiempos100mts de tipo lista que contiene los tiempos que tardaron los 10 alumnos en correr 100 metros
Tiempos100mts = [7, 6, 9, 5.6, 9.5, 4.5, 8, 7.3, 2, 4.8, 9.6]

#despejamos los valores de la lista
print(Tiempos100mts)
# Out:
# [7, 6, 9, 5.6, 9.5, 4.5, 8, 7.3, 2, 4.8, 9.6]

# %%
# Usamos la funcion mean para determinar el timpo promedio de la lista de valores
print ('El tiempo promedio de lo que corre es: ' + str(mean(Tiempos100mts)))
# Out:
# El tiempo promedio de lo que corre es: 6.663636363636363

# %%
#usamos la funcion median para determinar el tiempo promedio de la lista de valores

#definimos una variable llamada mediana para calcular la madiana de la lista con la funcion median

from statistics import median
mediana = median(Tiempos100mts)
print ('El tiempo promedio de lo que corre es: ' + str(mediana))
# Out:
# El tiempo promedio de lo que corre es: 7

# %% [markdown]
# Funcion miltimode para calcular multiples modas (Por ejemplo, en caso de que sea bimodal)

# %%
from statistics import multimode
multimodas = multimode(Tiempos100mts)
print ('La moda de los tiempos es: ' + str(multimodas))
# Out:
# La moda de los tiempos es: [7, 6, 9, 5.6, 9.5, 4.5, 8, 7.3, 2, 4.8, 9.6]

# %% [markdown]
# Ejemplo 3: Histograma de 2 grupos

# %%
#libreria pyton para fabricar valores
import matplotlib.pyplot as plt

# %%
import random
fabrica1 =[]
for i in range(100):
  numero_aleatorio = round(random.uniform(50,100), 2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [80.67, 72.95, 98.85, 58.83, 94.45, 78.85, 70.52, 76.54, 91.35, 68.42, 94.77, 50.98, 93.65, 69.92, 51.14, 71.7, 71.2, 57.58, 95.63, 69.99, 79.88, 69.17, 78.36, 55.51, 66.78, 96.97, 55.35, 62.04, 81.77, 61.24, 73.63, 72.47, 87.26, 67.55, 50.78, 50.77, 64.68, 60.43, 72.22, 83.09, 78.34, 76.26, 93.31, 77.53, 57.02, 96.84, 83.49, 59.91, 87.11, 52.2, 67.94, 52.0, 80.52, 78.71, 97.0, 66.71, 69.89, 92.91, 58.36, 64.13, 79.37, 93.19, 69.99, 89.85, 79.21, 94.97, 69.19, 53.35, 61.18, 59.4, 61.59, 96.27, 71.16, 60.99, 85.46, 54.07, 56.53, 65.95, 59.43, 67.9, 80.51, 80.86, 79.44, 71.77, 62.29, 75.39, 75.27, 53.72, 88.74, 59.97, 56.54, 79.06, 90.45, 76.11, 88.98, 71.1, 70.89, 83.53, 96.14, 80.04]

# %%
plt.hist(fabrica1)
plt.title("Produccion diaria de la fabrica 1")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la fabrica 1')

# %%
import random
fabrica1 =[]
for i in range(100):
  numero_aleatorio = round(random.uniform(50,100), 2)
  fabrica1.append(numero_aleatorio)

from statistics import mean, median, mode

media1 = mean (fabrica1)
mediana1 = median (fabrica1)
moda1 = mode (fabrica1)

print("valores de la fabrica 1")
print("la media es=", media1)
print("la mediana es=", mediana1)
print("la moda es=", moda1)
# Out:
# valores de la fabrica 1
# la media es= 73.206
# la mediana es= 71.05
# la moda es= 70.08

# %%
import random

fabrica2 =[]
for i in range(100):
  numero_aleatorio = round(random.uniform(40,90), 2)
  fabrica2.append(numero_aleatorio)

print(fabrica2)
# Out:
# [48.99, 73.3, 86.72, 76.6, 52.09, 66.56, 80.42, 54.55, 53.72, 55.92, 68.41, 69.44, 82.19, 51.84, 57.41, 41.25, 82.59, 54.8, 75.42, 65.12, 82.86, 74.9, 58.48, 53.65, 63.38, 62.0, 57.81, 88.73, 56.18, 82.78, 74.09, 44.46, 77.5, 67.94, 53.43, 69.88, 71.04, 85.43, 67.72, 57.62, 59.22, 44.05, 59.77, 78.86, 89.95, 74.75, 51.21, 88.53, 63.8, 56.0, 86.53, 87.2, 79.79, 84.2, 56.81, 63.46, 52.28, 55.93, 85.71, 69.61, 64.78, 71.43, 62.3, 79.48, 55.13, 81.7, 80.42, 63.52, 68.63, 59.93, 63.9, 53.18, 73.55, 52.79, 77.75, 71.07, 88.33, 70.77, 48.31, 62.42, 69.47, 56.32, 42.28, 71.08, 55.93, 44.92, 71.82, 42.14, 83.43, 46.58, 80.08, 81.38, 42.58, 67.53, 70.11, 44.11, 77.55, 44.19, 62.68, 45.51]

# %%
from statistics import mean, median, mode

media2 = mean (fabrica2)
mediana2 = median (fabrica2)
moda2 = mode (fabrica2)

print("valores de la fabrica 2")
print("la media es=", media2)
print("la mediana es=", mediana2)
print("la moda es=", moda2)
# Out:
# valores de la fabrica 2
# la media es= 65.8396
# la mediana es= 65.84
# la moda es= 80.42

# %%
import matplotlib.pyplot as plt

plt.hist(fabrica2)
plt.title("Produccion diaria de la fabrica 2")
plt.xlabel("Valores")
plt.ylabel("Frecuencia")
plt.show()
