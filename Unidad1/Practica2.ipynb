# %% [markdown]
# <a href="https://colab.research.google.com/github/CorralMarquez/Probabilidad-/blob/main/Unidad1/Practica2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from statistics import mean

# %%
Grupos =[70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]
type (Grupos)
print(Grupos)
# Out:
# [70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]

# %%
# En caso de que exista mas de una moda, se puede emplear la funcion miltimode para sacar las multiples modas que pueden existir

from statistics import multimode
moda2 = multimode(Grupos)
print(moda2)
# Out:
# [100]

# %% [markdown]
# Ejemplo2. Tiempo de 100 metros de un grupo de 12 alumnos

# %%
#definimos una de las variables llamada tiempos100mts de tipo lista que contiene los tiempos que tardaron los 10 alumnos en correr 100 metros
Tiempos100mts = [7, 6, 9, 5.6, 9.5, 4.5, 8, 7.3, 2, 4.8, 9.6]

#despejamos los valores de la lista
print(Tiempos100mts)
# Out:
# [70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]

# %%
# Usamos la funcion mean para determinar el timpo promedio de la lista de valores
print ('El tiempo promedio de lo que corre es: ' + str(mean(Tiempos100mts)))
# Out:
# El tiempo promedio de lo que corre es: 75.81818181818181

# %%
#usamos la funcion median para determinar el tiempo promedio de la lista de valores

#definimos una variable llamada mediana para calcular la madiana de la lista con la funcion median

from statistics import median
mediana = median(Tiempos100mts)
print ('El tiempo promedio de lo que corre es: ' + str(mediana))
# Out:
# El tiempo promedio de lo que corre es: 80

# %% [markdown]
# Funcion miltimode para calcular multiples modas (Por ejemplo, en caso de que sea bimodal)

# %%
from statistics import multimode
multimodas = multimode(Tiempos100mts)
print ('La moda de los tiempos es: ' + str(multimodas))
# Out:
# La moda de los tiempos es: [100]

# %% [markdown]
# Ejemplo 3: Histograma de 2 grupos

# %%
import random
fabrica1 =[]
for i in range(100):
  numero_aleatorio = round(random.uniform(50,100), 2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [53.22, 73.47, 55.66, 72.88, 97.15, 94.76, 85.49, 87.23, 58.92, 54.91, 95.92, 93.61, 98.62, 93.02, 85.14, 75.78, 75.65, 53.37, 52.99, 88.79, 93.86, 75.56, 73.14, 91.41, 60.05, 74.46, 98.71, 89.91, 91.62, 64.02, 86.09, 69.53, 54.76, 90.32, 59.35, 58.68, 61.86, 79.75, 98.92, 55.55, 92.59, 57.37, 50.75, 71.21, 63.18, 90.68, 54.66, 69.58, 76.3, 78.67, 90.99, 96.53, 82.63, 75.31, 95.83, 66.41, 74.75, 58.72, 95.51, 98.69, 53.07, 50.28, 53.04, 54.97, 65.66, 92.51, 93.66, 97.05, 72.03, 60.73, 86.82, 53.89, 87.19, 56.15, 99.32, 59.55, 53.35, 95.28, 92.95, 87.02, 55.75, 60.27, 64.68, 60.64, 52.68, 62.82, 59.46, 51.38, 55.65, 73.33, 59.08, 52.47, 93.85, 86.03, 91.74, 53.73, 85.69, 58.29, 65.22, 83.34]

# %%
#libreria pyton para fabricar valores
import matplotlib.pyplot as plt

# %%
plt.hist(fabrica1)
plt.title("Produccion diaria de la fabrica 1")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la fabrica 1')

# %%
from statistics import mean, median, mode

media1 = mean (fabrica1)
mediana1 = median (fabrica1)
moda1 = mode (fabrica1)

print("valores de la fabrica 1")
print("la media es=", media1)
print("la mediana es=", mediana1)
print("la moda es=", moda1)
# Out:
# valores de la fabrica 1
# la media es= 74.0511
# la mediana es= 73.4
# la moda es= 53.22
